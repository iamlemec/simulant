# %%
plt = plotter()
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
import jax
import jax.numpy as np
import jax.lax as lax
import jax.nn as nn
import haiku as hk
import optax

# %%
import rl_haiku as rlh

# %%
θpol, θval = rlh.solve_iterate(R=10000, εpol=1e-4, εval=1e-4)
poly = rlh.fpol.apply(θpol, rlh.grid1)
valu = rlh.fval.apply(θval, rlh.grid1)[:, 0]
valu1 = rlh.eval_policy(θpol, θval)

# %%
plt.plot(rlh.grid, poly);

# %%
plt.plot(rlh.grid, valu, rlh.grid, valu1);
