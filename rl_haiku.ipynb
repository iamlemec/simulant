# %%
plt = plotter()
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
import jax
import jax.numpy as np
import jax.lax as lax
import jax.nn as nn
import haiku as hk
import optax

# %%
import rl_haiku as rlh

# %%
θval = rlh.solve_iterate(R=5000, Mval=0.1, Δval=0.01)
poly = rlh.max_policy(θval)
valu = rlh.get_value(θval, rlh.grid1)
valu1 = rlh.eval_policy(θval, θval)

# %%
plt.plot(rlh.grid, poly);

# %%
plt.plot(rlh.grid, valu, rlh.grid, valu1);
